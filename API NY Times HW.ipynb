# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Array to hold sentiment
sentiments_all = []
# Counter
counter = 1

# %%
target_user = ['@BBCNews', '@CBSNews', '@CNN', '@FoxNews', '@NYT']

# %%
# Loop through all target users# Loop t 
for target in target_user:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(target, page=x)
        # Loop through all tweets 
        for tweet in public_tweets:
        
            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter
            
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)


            # Add sentiments for each tweet into an array
            sentiments_all.append({"User": target, 
                           "Source account": tweet["source"],
                           "Date": tweet["created_at"],        
                           "Text": tweet["text"],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
            
            
            # Add to counter 
            counter = counter + 1
    
    

print(sentiments_all)
print("")
# Out:
# [{'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 22:25:21 +0000 2018', 'Text': "May says G7 will act over Russia's 'malign activity' https://t.co/3NOnT0IThk", 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 1}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 22:16:18 +0000 2018', 'Text': "G7 commits to 'rules-based trading system' despite tensions with US https://t.co/bapRU3DoKM", 'Compound': 0.3309, 'Positive': 0.272, 'Negative': 0.728, 'Neutral': 0.0, 'Tweets Ago': 2}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 22:09:04 +0000 2018', 'Text': 'Tyson Fury: Briton beats Sefer Seferi in comeback fight https://t.co/OZ6jh5Q6V1', 'Compound': -0.743, 'Positive': 0.0, 'Negative': 0.559, 'Neutral': 0.441, 'Tweets Ago': 3}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 21:52:35 +0000 2018', 'Text': 'First Test: Argentina 10-23 Wales https://t.co/lotpAFrYfI', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 4}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 21:35:59 +0000 2018', 'Text': 'Terry Flanagan loses to Maurice Hooker in fight for vacant WBO super-lightweight title https://t.co/j3zqqNhhAJ', 'Compound': -0.5994, 'Positive': 0.0, 'Negative': 0.71, 'Neutral': 0.29, 'Tweets Ago': 5}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 21:10:44 +0000 2018', 'Text': 'World Cup warm-up match: Spain 1-0 Tunisia https://t.co/qdiX0IsEwq', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 6}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 20:42:33 +0000 2018', 'Text': 'World record set for largest skinny dip on Co Wicklow beach https://t.co/LUb3JfEqSK', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 7}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 20:19:43 +0000 2018', 'Text': 'House in flames after lightning strike near Lenzie https://t.co/xPExU3zQLG', 'Compound': -0.128, 'Positive': 0.0, 'Negative': 0.842, 'Neutral': 0.158, 'Tweets Ago': 8}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 19:26:19 +0000 2018', 'Text': 'Sebastian Vettel on pole in Canada https://t.co/salEJlFiT9', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 9}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 19:26:19 +0000 2018', 'Text': 'Disruptive passenger on Jet2 flight banned for life https://t.co/rxjp1YOOcw', 'Compound': -0.6486, 'Positive': 0.0, 'Negative': 0.569, 'Neutral': 0.431, 'Tweets Ago': 10}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 19:12:31 +0000 2018', 'Text': 'Welsh Labour leader-selection row points to wider struggle https://t.co/86PEpTGs58', 'Compound': -0.3182, 'Positive': 0.0, 'Negative': 0.777, 'Neutral': 0.223, 'Tweets Ago': 11}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Sat Jun 09 19:01:08 +0000 2018', 'Text': "Trump at G7: Who's who in Merkel's photo? https://t.co/OGZos8I875", 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 12}, {'User': '@BBCNews', 'Source account': '<a href="http://www.socialflow.co ...

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments_all)
sentiments_pd
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.0000  Sat Jun 09 22:25:21 +0000 2018     1.000    0.000     0.000
# 1      0.3309  Sat Jun 09 22:16:18 +0000 2018     0.728    0.000     0.272
# 2     -0.7430  Sat Jun 09 22:09:04 +0000 2018     0.559    0.441     0.000
# 3      0.0000  Sat Jun 09 21:52:35 +0000 2018     1.000    0.000     0.000
# 4     -0.5994  Sat Jun 09 21:35:59 +0000 2018     0.710    0.290     0.000
# 5      0.0000  Sat Jun 09 21:10:44 +0000 2018     1.000    0.000     0.000
# 6      0.0000  Sat Jun 09 20:42:33 +0000 2018     1.000    0.000     0.000
# 7     -0.1280  Sat Jun 09 20:19:43 +0000 2018     0.842    0.158     0.000
# 8      0.0000  Sat Jun 09 19:26:19 +0000 2018     1.000    0.000     0.000
# 9     -0.6486  Sat Jun 09 19:26:19 +0000 2018     0.569    0.431     0.000
# 10    -0.3182  Sat Jun 09 19:12:31 +0000 2018     0.777    0.223     0.000
# 16   Hailstorm halts M9 motorway traffic https://t....          17  @BBCNews
# 17   Stalking victim calls for harsher sentences ht...          18  @BBCNews
# 18   RT @BBCWorld: Inside Afghanistan's only secure...          19  @BBCNews
# 19   RT @BBCWorld: Russian workers being taught how...          20  @BBCNews
# 20   May says G7 will act over Russia's 'malign act...          21  @BBCNews
# 21   G7 commits to 'rules-based trading system' des...          22  @BBCNews
# 22   Tyson Fury: Briton beats Sefer Seferi in comeb...          23  @BBCNews
# 23   First Test: Argentina 10-23 Wales https://t.co...          24  @BBCNews
# 24   Terry Flanagan loses to Maurice Hooker in figh...          25  @BBCNews
# 25   World Cup warm-up match: Spain 1-0 Tunisia htt...          26  @BBCNews
# 26   World record set for largest skinny dip on Co ...          27  @BBCNews
# 27   House in flames after lightning strike near Le...          28  @BBCNews
# 28   Sebastian Vettel on pole in Canada https://t.c...          29  @BBCNews
# 29   Disruptive passenger on Jet2 flight banned for...          30  @BBCNews
# ..                                                 ...         ...       ...
# 470  atmosphere: The Rich Are Planning to Leave Thi...         471      @NYT
# 471  Check In: At a London Hotel, Art Deco Design a...         472      @NYT
# 472  U.N. Imposes Sanctions on 6 for Trafficking Li...         473      @NYT
# 473  Playlist: The Playlist: Kanye West’s Breakout ...         474      @NYT
# 474  Review: Pulled Apart by ‘Love and Intrigue’. h...         475      @NYT
# 475  To Conduct Its Parks Concerts, the Philharmoni...         476      @NYT
# 476  The Shortlist: 3 New Novels on the Perils of D...         477      @NYT
# 477  The Best, Worst and Scariest of This Week’s Mo...         478      @NYT
# 478  The Poetic Justice of Stella Abrera’s Juliet. ...         479      @NYT
# 479  Critic’s Notebook: High School Musicians Take ...         480      @NYT
# 480  Lisa Edelstein Says Goodbye to Her ‘Girlfriend...         481      @NYT
# 481  A Word With: Kevin Costner Revisits the Americ...         482      @NYT
# 482  Streaming: ‘Caravaggio’ and Other Pleasures an...         483      @NYT
# 483  11 of Our Best Weekend Reads. https://t.co/lr5...         484      @NYT
# 484  Art Is Becoming a Financial Product, and Block...         485      @NYT
# 485  RuPaul’s Drag Race: ‘RuPaul’s Drag Race’ Seaso...         486      @NYT
# 486  ‘You Have to Be Girl-Power Tough’: Pageant Com...         487      @NYT
# 487  This Week: Philharmonic Concerts in the Parks,...         488      @NYT
# 488  He Literally Wrote the Book on Fabulousness. h...         489      @NYT
# 489  New York Today: New York Today: 5 Reasons to W...         490      @NYT
# 490  Best of Late Night: Colbert Wants Trump to Pre...         491      @NYT
# 491  Crime: Dangerous Disappearing Acts, With Kille...         492      @NYT
# 492  Inside the List: Everything Is Copy. https://t...         493      @NYT
# 493  New in Paperback: ‘Rising Star,’ ‘Mrs. Fletche...         494      @NYT
# 494  The Shortlist: The Struggles of Modern Motherh...         495      @NYT
# 495  Fiction: A Persian Turned Parisian Insists: I’...         496      @NYT
# 496  Our Back Pages: Notes From the Book Review Arc...         497      @NYT
# 497  What’s on TV Friday: ‘Sense8’ and ‘Just Anothe...         498      @NYT
# 498  David Douglas Duncan, 102, Who Photographed th...         499      @NYT
# 499  Op-Ed Columnist: The Price of an Incompetent P...         500      @NYT
#
# [500 rows x 9 columns]

# %%
sentiments_pd.to_csv("../Instructions/media_sentiments_analysis.csv", encoding="utf-8", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-054ac5fc1ccd> in <module>()
# ----> 1 sentiments_pd.to_csv("../Instructions/media_sentiments_analysis.csv", encoding="utf-8", index=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Instructions/media_sentiments_analysis.csv'

# %%
BBC_compound = sentiments_pd.loc["BBC", "Compound"]
CBS_compound = sentiments_pd.loc["CBS", "Compound"] 
CNN_compound = sentiments_pd.loc["CNN", "Compound"] 
Fox_compound = sentiments_pd.loc["FoxNews", "Compound"] 
nytimes_compound = sentiments_pd.loc["nytimes", "Compound"] 
BBC_compound =BBC_compound.reset_index()
CBS_compound =CBS_compound.reset_index()
CNN_compound =CNN_compound.reset_index()
Fox_compound =Fox_compound.reset_index()
nytimes_compound =nytimes_compound.reset_index()

# %%
Compound_df=pd.concat([BBC_compound, CBS_compound, CNN_compound, Fox_compound,nytimes_compound],axis=1)
Compound_df
Compound_df.columns.values[1] = 'BBC Compound' 
Compound_df.columns.values[3] = 'CBS Compound'
Compound_df.columns.values[5] = 'CNN Compound'
Compound_df.columns.values[7] = 'FoxNews Compound'
Compound_df.columns.values[9] = 'NYtimes Compound'
Compound_df.head()

# %%
x = np.arange(100, 0, -1)
a = plt.scatter(x, df['@BBCNews'], alpha=0.5)
b = plt.scatter(x, df['@CBSNews'], alpha=0.5)
c = plt.scatter(x, df['@CNN'], alpha=0.5)
d = plt.scatter(x, df['@FoxNews'], alpha=0.5)
e = plt.scatter(x, df['@NYT'], alpha=0.5)
plt.title('Sentiment Analysis of Tweets')
plt.xlabel('Number of Tweets Ago')
plt.ylabel('Compound Sentiment Score')
plt.gca().invert_xaxis()
plt.legend((a,b,c,d,e),('@BBCNews', '@CBSNews','@CNN', '@FoxNews', '@nytimes'),numpoints=1, loc='upper right', ncol=1, fontsize=8)
lgd = plt.legend(bbox_to_anchor=(1, 1))
plt.savefig('Sentiment_scatter_plot.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
df_mean.plot(kind='bar')
plt.title('Average Sentiment Score of Last 100 Tweets')
plt.xlabel('News Organization')
plt.ylabel('Average Sentiment Score')
plt.savefig('Sentiment_Avg.png')
plt.tight_layout()
plt.show()
